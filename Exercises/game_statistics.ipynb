# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("..\game_statistics_feb_2023.csv") #Read the Data
columns=list(df.keys())
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3203: DtypeWarning: Columns (1,2,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(30)
# Out:
#                               title total_sales total_shipped  \
# 0                  Professor Layton         NaN        18.00m
# 1       Need for Speed: Most Wanted         NaN        17.80m
# 2   Pokémon Diamond / Pearl Version         NaN        17.67m
# 3                        Elden Ring         NaN        17.50m
# 4       Grand Theft Auto: Vice City         NaN        17.50m
# 5     Grand Theft Auto: San Andreas         NaN        17.30m
# 6               Super Mario Bros. 3         NaN        17.28m
# 7              RollerCoaster Tycoon         NaN        17.23m
# 8                           Persona         NaN        17.10m
# 9                       SoulCalibur         NaN        17.00m
# 10                             Zuma         NaN        17.00m
# 11                             Zuma         NaN        17.00m
# 12                      Garry's Mod         NaN        16.90m
# 13          Pokemon Mystery Dungeon         NaN        16.86m
# ...
